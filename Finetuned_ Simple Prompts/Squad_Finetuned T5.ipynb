# %%
# !pip install transformers==2.9.0
# !nvidia-smi
# Out:
# Requirement already satisfied: transformers==2.9.0 in /usr/local/lib/python3.7/dist-packages (2.9.0)
# Requirement already satisfied: tokenizers==0.7.0 in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (3.6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (0.0.53)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (2019.12.20)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (0.1.96)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==2.9.0) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==2.9.0) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.9.0) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.9.0) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==2.9.0) (7.1.2)
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import random
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AdamW,
    T5ForConditionalGeneration,
    T5Tokenizer,
    get_linear_schedule_with_warmup
)
def set_seed(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
set_seed(42)

# %%
tokenizer = T5Tokenizer.from_pretrained('t5-base')
t5_model = T5ForConditionalGeneration.from_pretrained('drive/MyDrive/outputs/model_files')

# %%
# optimizer
no_decay = ["bias", "LayerNorm.weight"]
optimizer_grouped_parameters = [
    {
        "params": [p for n, p in t5_model.named_parameters() if not any(nd in n for nd in no_decay)],
        "weight_decay": 0.0,
    },
    {
        "params": [p for n, p in t5_model.named_parameters() if any(nd in n for nd in no_decay)],
        "weight_decay": 0.0,
    },
]
optimizer = AdamW(optimizer_grouped_parameters, lr=3e-4, eps=1e-8)

# %%
true_false_adjective_tuples = [
                               (("Can you lend me some money?",	"I'm completely broke until payday."), "no"), 
                               (("Do you think he did the theft?",	"He is as innocent as a lamb"), "no"),
                               (("Are you sure you want the spoiler",	"haha sure. by the time, I get to it; I will forget the details, only knowing that it's touching at the end"),"yes"),
                               (("Does tomorrow afternoon work for you?",	"Yeah tomorrow afternoon works for me."),	"yes"),
                               (("oh wow, Cuban cigar? I've never smoke before",	"This one is actually from Peru, which is more my taste."),	"no"),
                               (("Are you sending them an invitation?",	"Certainly."),	"yes"),
                               (("You, uh, you don't want to go for a ride, do you?",	"Is it safe?"),	'yes'),
                               (("Have you ever made them yourself?",	"no. only eat them"),	"no"),
                               (("Have you seen my watch?",	"I will take a look for it around my house."),	"no"),
                               (("You don't look normal. Are you all right?", "I have a headache."),	"no"),
                               (("any improvements in your marathon time?",	"No, only a few minutes. I still find it difficult to run long races"),	"no"),
                               (("do you live near San Mateo?",	"no, but I'm willing to drive for good ramen"),	"no"),
                               (("Can he play the violin?",	"Can a pig fly?"),	"no"),
                               (("Aren't you scared?", "Sometimes."),	"yes")
]

# %%
t5_model.train()

epochs = 10

for epoch in range(epochs):
  print ("epoch ",epoch)
  for input,output in true_false_adjective_tuples:
    input_sent = "Answer 'yes' or 'no' based on the intention of the response: "+input[0] + input[1]+ " </s>"
    ouput_sent = output+" </s>"

    tokenized_inp = tokenizer.encode_plus(input_sent,  max_length=96, pad_to_max_length=True,return_tensors="pt")
    tokenized_output = tokenizer.encode_plus(ouput_sent, max_length=96, pad_to_max_length=True,return_tensors="pt")


    input_ids  = tokenized_inp["input_ids"]
    attention_mask = tokenized_inp["attention_mask"]

    lm_labels= tokenized_output["input_ids"]
    decoder_attention_mask=  tokenized_output["attention_mask"]


    # the forward function automatically creates the correct decoder_input_ids
    output = t5_model(input_ids=input_ids, lm_labels=lm_labels,decoder_attention_mask=decoder_attention_mask,attention_mask=attention_mask)
    loss = output[0]

    loss.backward()
    optimizer.step()
    optimizer.zero_grad()
# Out:
# epoch  0
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:155: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1055.)
#   exp_avg.mul_(beta1).add_(1.0 - beta1, grad)
# epoch  1
# epoch  2
# epoch  3
# epoch  4
# epoch  5
# epoch  6
# epoch  7
# epoch  8
# epoch  9

# %%
import csv
file = csv.reader(open('testing.csv'))
correct = 0
wrong = 0
total = 0
tp = 0
tn = 0
fp = 0
fn = 0
for line in file:
  test_sent = "Answer 'yes' or 'no' based on the intention of the response:" + line[0] + "</s>"
  print(test_sent)
  test_tokenized = tokenizer.encode_plus(test_sent, return_tensors="pt")

  test_input_ids  = test_tokenized["input_ids"]
  test_attention_mask = test_tokenized["attention_mask"]

  t5_model.eval()
  beam_outputs = t5_model.generate(
      input_ids=test_input_ids,attention_mask=test_attention_mask,
      max_length=64,
      early_stopping=True,
      num_beams=10,
      num_return_sequences=1,
      no_repeat_ngram_size=2
  )

  for beam_output in beam_outputs:
      sent = tokenizer.decode(beam_output, skip_special_tokens=True,clean_up_tokenization_spaces=True)
      print ("Prediction:", sent, "Actual", line[1])
      if sent == line[1]:
        correct += 1
      else:
        wrong += 1
      if sent == 'yes' and line[1] == 'yes':
        tp += 1
      elif sent == 'yes' and line[1] == 'no':
        fp += 1
      elif sent == 'no' and line[1] == 'yes':
        fn += 1
      elif sent == 'no' and line[1] == 'no':
        tn += 1
      print(correct, wrong)
  print("")
  total += 1
  print(total)
# Out:
# Answer 'yes' or 'no' based on the intention of the response:Did you tell her about the dress?I just bit my tongue.</s>
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py:1432: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   beam_id = beam_token_id // vocab_size
# Prediction: no Actual no
# 1 0
#
# 1
# Answer 'yes' or 'no' based on the intention of the response:Will you stay if we promise to be good?Och! That's a piecrust promise. Easily made, easily broken.</s>
# Prediction: no Actual no
# 2 0
#
# 2
# Answer 'yes' or 'no' based on the intention of the response:Ever heard of it?No, what is it about?</s>
# Prediction: no Actual no
# 3 0
#
# 3
# Answer 'yes' or 'no' based on the intention of the response:Do you play pingpong often?No, very rarely. It's kind of amazing that I won, but I'm still taking credit for it.</s>
# Prediction: no Actual no
# 4 0
#
# 4
# Answer 'yes' or 'no' based on the intention of the response:Does this look good?That's it weirdo!</s>
# Prediction: yes Actual no
# 4 1
#
# 5
# Answer 'yes' or 'no' based on the intention of the response:Do you have any plans?Yes, no shopping plans but I can't wait to eat thanksgiving food.</s>
# Prediction: no Actual yes
# 4 2
#
# 6
# Answer 'yes' or 'no' based on the intention of the response:Is someone unable to breathe, sir?It is, I believe, cardiac arrest.</s>
# Prediction: yes Actual yes
# 5 2
#
# 7
# Answer 'yes' or 'no' based on the intention of the response:Are you working part time?No, I'm working full time!</s>
# Prediction: no Actual no
# 6 2
#
# 8
# Answer 'yes' or 'no' based on the intention of the response:Does he have work?He is as busy as a bee.</s>
# Prediction: no Actual yes
# 6 3
#
# 9
# Answer 'yes' or 'no' based on the intention of the response:Do you always prefer lunch sync over regular meeting syncs?Yeah right, I heard the food there is good. I am not sure what they serve there for lunch? On wednesdays.</s>
# Prediction: yes Actual yes
# 7 3
#
# 10
# Answer 'yes' or 'no' based on the intention of the response:Are you leaving at dawn for South America?the night's still young!...</s>
# Prediction: no Actual yes
# 7 4
#
# 11
# Answer 'yes' or 'no' based on the intention of the response:Is it hard?not really, it just requires a lot of patience.</s>
# Prediction: yes Actual no
# 7 5
#
# 12
# Answer 'yes' or 'no' based on the intention of the response:Do you enjoy fishing underwater?I detest it.</s>
# Prediction: yes Actual no
# 7 6
#
# 13
# Answer 'yes' or 'no' based on the intention of the response:did you see it?nope, what does it say?</s>
# Prediction: yes Actual no
# 7 7
#
# 14
# Answer 'yes' or 'no' based on the intention of the response:Do you have time right now?I'm afraid not, right now I'm in a meeting and I'll be going for lunch afterwards. How about tomorrow at noon?</s>
# Prediction: yes Actual no
# 7 8
#
# 15
# Answer 'yes' or 'no' based on the intention of the response:Does that count as extreme?White water rafting, definitely!</s>
# Prediction: yes Actual yes
# 8 8
#
# 16
# Answer 'yes' or 'no' based on the intention of the response:We're supposed to believe that?That's right.</s>
# Prediction: yes Actual yes
# 9 8
#
# 17
# Answer 'yes' or 'no' based on the intention of the response:Have you ever visited the southern hemisphere?Yes! I've been to Australia.</s>
# Prediction: no Actual yes
# 9 9
#
# 18
# Answer 'yes' or 'no' based on the intention of the response:You getting this, Winifred?Every word.</s>
# Prediction: yes Actual yes
# 10 9
#
# 19
# Answer 'yes' or 'no' based on the intention of the response:Is the professor friendly?He is as cool as a cucumber.</s>
# Prediction: yes Actual yes
# 11 9
#
# 20
# Answer 'yes' or 'no' based on the intention of the response:haha thanks, do you plan any instruments?Yeah.... I play bit of guitar. Just got my first monitor this week</s>
# Prediction: no Actual yes
# 11 10
#
# 21
# Answer 'yes' or 'no' based on the intention of the response:Is your helper old?She’s as old as the hills.</s>
# Prediction: no Actual yes
# 11 11
#
# 22
# Answer 'yes' or 'no' based on the intention of the response:Have you been lifting for a long time?No, I am just a starter.</s>
# Prediction: no Actual no
# 12 11
#
# 23
# Answer 'yes' or 'no' based on the intention of the response:Did you book the tickets?Is rain wet?</s>
# Prediction: yes Actual yes
# 13 11
#
# 24
# Answer 'yes' or 'no' based on the intention of the response:do you watch a lot of TV showsNot a lot! But I preparing for a good vacation season</s>
# Prediction: no Actual no
# 14 11
#
# 25
# Answer 'yes' or 'no' based on the intention of the response:Is it hot outside?You could fry an egg on the sidewalk.</s>
# Prediction: yes Actual yes
# 15 11
#
# 26
# Answer 'yes' or 'no' based on the intention of the response:Have you been to Grand canyon?Actually not yet! May be something i can visit this christmas</s>
# Prediction: no Actual no
# 16 11
#
# 27
# Answer 'yes' or 'no' based on the intention of the response:So wait, I'm really the only heir?The one and only.</s>
# Prediction: no Actual yes
# 16 12
#
# 28
# Answer 'yes' or 'no' based on the intention of the response:Winifred, did I say that I was going to take the children to the bank?It certainly sounded that way, dear.</s>
# Prediction: no Actual yes
# 16 13
#
# 29
# Answer 'yes' or 'no' based on the intention of the response:Was that hot?The sun was scorching?</s>
# Prediction: yes Actual yes
# 17 13
#
# 30
# Answer 'yes' or 'no' based on the intention of the response:This is a costume?Aaaiyyyy... worked on it all night long!</s>
# Prediction: no Actual yes
# 17 14
#
# 31
# Answer 'yes' or 'no' based on the intention of the response:Can you drive that far?Can fish swim?</s>
# Prediction: yes Actual yes
# 18 14
#
# 32
# Answer 'yes' or 'no' based on the intention of the response:Can he feel it if I pet him?I guess.</s>
# Prediction: no Actual yes
# 18 15
#
# 33
# Answer 'yes' or 'no' based on the intention of the response:Did you argue with the clerk?I was really angry, but I managed to hold my tongue.</s>
# Prediction: no Actual no
# 19 15
#
# 34
# Answer 'yes' or 'no' based on the intention of the response:Could he hit?Lifetime 356 average. Third highest in history.</s>
# Prediction: no Actual yes
# 19 16
#
# 35
# Answer 'yes' or 'no' based on the intention of the response:are you just going home now?no, i'm going to get a massage first</s>
# Prediction: no Actual no
# 20 16
#
# 36
# Answer 'yes' or 'no' based on the intention of the response:Do you go often?Yeah I would say maybe every couple weeks or so what are your favorite cities to visit?</s>
# Prediction: no Actual yse
# 20 17
#
# 37
# Answer 'yes' or 'no' based on the intention of the response:Is he generous?He would give you the shirt off his back</s>
# Prediction: no Actual yes
# 20 18
#
# 38
# Answer 'yes' or 'no' based on the intention of the response:Did you do anything fun over the weekend?Yes, the darkness can be a bit depressing. This weekend I went rock climbing! It was great!</s>
# Prediction: yes Actual yes
# 21 18
#
# 39
# Answer 'yes' or 'no' based on the intention of the response:Have you seen Rick and Morty ?Yup! I watch that show with my friends I haven't gotten very far in it though</s>
# Prediction: no Actual yes
# 21 19
#
# 40
# Answer 'yes' or 'no' based on the intention of the response:Is it scary?Snow is not scary as long as you're prepared.</s>
# Prediction: yes Actual no
# 21 20
#
# 41
# Answer 'yes' or 'no' based on the intention of the response:That cake looks delicious. Aren't you going to have some with me?But that was a huge meal we just had.</s>
# Prediction: no Actual no
# 22 20
#
# 42
# Answer 'yes' or 'no' based on the intention of the response:Should I go straight at this intersection?Hang a left.</s>
# Prediction: yes Actual no
# 22 21
#
# 43
# Answer 'yes' or 'no' based on the intention of the response:Please stay for dinner. Would you like to stay forever?Dinner would be great.</s>
# Prediction: yes Actual no
# 22 22
#
# 44
# Answer 'yes' or 'no' based on the intention of the response:Ever been to New York?No, I've never been to the East Coast, thinking of going after the winter, I don't like the cold.</s>
# Prediction: no Actual no
# 23 22
#
# 45
# Answer 'yes' or 'no' based on the intention of the response:Should it not be a wonderful, romantic moment?sorry, lady. There's no time.</s>
# Prediction: yes Actual yes
# 24 22
#
# 46
# Answer 'yes' or 'no' based on the intention of the response:Do you believe in reincarnation?yea but then you will forget things. I hope Neural Link work out</s>
# Prediction: yes Actual yes
# 25 22
#
# 47
# Answer 'yes' or 'no' based on the intention of the response:Do you have any plans?Yes, no shopping plans but I can't wait to eat thanksgiving food.</s>
# Prediction: no Actual yes
# 25 23
#
# 48
# Answer 'yes' or 'no' based on the intention of the response:did you watch?haha, nope I don't watch it, but my roommate is super into it what other TV shows do you like?</s>
# Prediction: no Actual no
# 26 23
#
# 49
# Answer 'yes' or 'no' based on the intention of the response:have you seen any good movies lately?I watched a few lately, but nothing is as good as Avatar.</s>
# Prediction: no Actual yes
# 26 24
#
# 50
# Answer 'yes' or 'no' based on the intention of the response:So you think now everything's gonna turn back to normal?As normal as it could be.</s>
# Prediction: yes Actual yes
# 27 24
#
# 51
# Answer 'yes' or 'no' based on the intention of the response:Are you taking this the road to med school?I'm going to try.</s>
# Prediction: no Actual yes
# 27 25
#
# 52
# Answer 'yes' or 'no' based on the intention of the response:You thought we weren't?I thought it might've been one of those made things that adults tell kids...</s>
# Prediction: yes Actual yes
# 28 25
#
# 53
# Answer 'yes' or 'no' based on the intention of the response:Will he really give us that test?Does the sun come up in the east these days?</s>
# Prediction: no Actual yes
# 28 26
#
# 54
# Answer 'yes' or 'no' based on the intention of the response:New York must be snowing right?Yes. I was actually just there a few weeks ago for Thanksgiving and got to see the first snow of the season!</s>
# Prediction: no Actual yes
# 28 27
#
# 55
# Answer 'yes' or 'no' based on the intention of the response:Do you play soccer often?Yes, but I'm terrible at it.</s>
# Prediction: no Actual yes
# 28 28
#
# 56
# Answer 'yes' or 'no' based on the intention of the response:You okay?More or less.</s>
# Prediction: yes Actual yes
# 29 28
#
# 57
# Answer 'yes' or 'no' based on the intention of the response:Isn't it fantastic?it - it's great. Now let's get outta here.</s>
# Prediction: yes Actual yes
# 30 28
#
# 58
# Answer 'yes' or 'no' based on the intention of the response:You don't add some kind of special sauce or something?Don't have to. To make something special, you just have to believe it's special.</s>
# Prediction: no Actual no
# 31 28
#
# 59
# Answer 'yes' or 'no' based on the intention of the response:It's the world dear, did you expect it to be small?Smaller...</s>
# Prediction: yes Actual yes
# 32 28
#
# 60
# Answer 'yes' or 'no' based on the intention of the response:Does it make sense?I think so. thanks for your point!</s>
# Prediction: yes Actual yes
# 33 28
#
# 61
# Answer 'yes' or 'no' based on the intention of the response:Haha are you looking forward to the weekend?Yeah, gonna watch <REDACTED_TERM> with my friends. First time. So excited.</s>
# Prediction: yes Actual yes
# 34 28
#
# 62
# Answer 'yes' or 'no' based on the intention of the response:Have you been there?It's a mountain. Mountains are safe.Mountains have caves. And water. And sticks.</s>
# Prediction: yes Actual yes
# 35 28
#
# 63
# Answer 'yes' or 'no' based on the intention of the response:And marriage, does that get easier?It's hard. We started going to a marriage counselor.</s>
# Prediction: yes Actual no
# 35 29
#
# 64
# Answer 'yes' or 'no' based on the intention of the response:Is he smart?His brain is the size of a pea.</s>
# Prediction: no Actual no
# 36 29
#
# 65
# Answer 'yes' or 'no' based on the intention of the response:is this really necessary?Quite necessary, Fiona.</s>
# Prediction: yes Actual yes
# 37 29
#
# 66
# Answer 'yes' or 'no' based on the intention of the response:Is this your first time doing something like this?Yes, interesting task!</s>
# Prediction: yes Actual yes
# 38 29
#
# 67
# Answer 'yes' or 'no' based on the intention of the response:Do you have interesting plans?yea I'm travelling to Vancouver this weekend. what about you?</s>
# Prediction: yes Actual yes
# 39 29
#
# 68
# Answer 'yes' or 'no' based on the intention of the response:does he have a sort of mellow style?umm yes he has some but not all</s>
# Prediction: no Actual yes
# 39 30
#
# 69
# Answer 'yes' or 'no' based on the intention of the response:Would you say you have a sweet tooth?Yes. When my top favorite food looks like: cookies, M&M, danish cheese, etc.</s>
# Prediction: yes Actual yes
# 40 30
#
# 70
# Answer 'yes' or 'no' based on the intention of the response:You're all right?Cold and wet but alive.</s>
# Prediction: yes Actual no
# 40 31
#
# 71
# Answer 'yes' or 'no' based on the intention of the response:Ever see them play?I haven't Honestly I probably wouldn't be able to identify which sport they played</s>
# Prediction: no Actual no
# 41 31
#
# 72
# Answer 'yes' or 'no' based on the intention of the response:Does that make sense so far?yes</s>
# Prediction: yes Actual yes
# 42 31
#
# 73
# Answer 'yes' or 'no' based on the intention of the response:Are you good at <REDACTED_TERM>?not at all, but I want to practice more alright. I gotta go!</s>
# Prediction: yes Actual no
# 42 32
#
# 74
# Answer 'yes' or 'no' based on the intention of the response:Is it hard to find a place to play soccer or tennis indoors?yea. I enjoy playing outside though, just a little cold</s>
# Prediction: no Actual yes
# 42 33
#
# 75
# Answer 'yes' or 'no' based on the intention of the response:Are you looking for an expensive laptop?I’m looking for a reliable one that won’t break the bank.</s>
# Prediction: yes Actual no
# 42 34
#
# 76
# Answer 'yes' or 'no' based on the intention of the response:She really does love him, doesn't she, Sebastian?Well, it's like I always say, Your Majesty. Children got to be free to lead their own lives.</s>
# Prediction: no Actual yes
# 42 35
#
# 77
# Answer 'yes' or 'no' based on the intention of the response:Hello, I feel like I've met you before, can you remind me your name?It's on the screen! I don't recall meeting you.</s>
# Prediction: no Actual yes
# 42 36
#
# 78
# Answer 'yes' or 'no' based on the intention of the response:It's a sci-fi book about aliens and a type of virtual reality. Pique your interest at all?Slightly, I typically read fiction but I can curious what type of virtual reality is discussed in the book</s>
# Prediction: yes Actual yes
# 43 36
#
# 79
# Answer 'yes' or 'no' based on the intention of the response:Did he believe you?He swallowed it hook, line and sinker.</s>
# Prediction: no Actual yes
# 43 37
#
# 80
# Answer 'yes' or 'no' based on the intention of the response:Did you report Private Barnes to your superiors?I remember thinking very highly of Private Barnes, and not wanting to see his record tarnished by a formal charge.</s>
# Prediction: no Actual no
# 44 37
#
# 81
# Answer 'yes' or 'no' based on the intention of the response:But do you think next time we could go to the same game?No problem.</s>
# Prediction: no Actual yes
# 44 38
#
# 82
# Answer 'yes' or 'no' based on the intention of the response:have you graduated already?Yes, we graduated back in the seventies.</s>
# Prediction: yes Actual no
# 44 39
#
# 83
# Answer 'yes' or 'no' based on the intention of the response:Is she a chatterbox?She never stops talking.</s>
# Prediction: yes Actual yes
# 45 39
#
# 84
# Answer 'yes' or 'no' based on the intention of the response:You want me to come out there and play private eye?Consider it.</s>
# Prediction: no Actual yes
# 45 40
#
# 85
# Answer 'yes' or 'no' based on the intention of the response:Can I get that doll?Great! I'd love to get rid of it!</s>
# Prediction: yes Actual yes
# 46 40
#
# 86
# Answer 'yes' or 'no' based on the intention of the response:You want answers?I think I'm entitled to them.</s>
# Prediction: yes Actual yes
# 47 40
#
# 87
# Answer 'yes' or 'no' based on the intention of the response:Is it your job?Yeah, but I part time work on a farm. Helping with a bit of everything</s>
# Prediction: no Actual yes
# 47 41
#
# 88
# Answer 'yes' or 'no' based on the intention of the response:Do you still talk to the people you met?Not really. The interactions are usually short-lived but it's fascinating to learn where people are coming from and what matters to them</s>
# Prediction: yes Actual no
# 47 42
#
# 89
# Answer 'yes' or 'no' based on the intention of the response:Do you go to the gym often?I go everyday. In fact, I'm in a running challenge.</s>
# Prediction: no Actual yes
# 47 43
#
# 90
# Answer 'yes' or 'no' based on the intention of the response:have you been to the US?yeah. I studied English there for a while. Awesome experience</s>
# Prediction: no Actual yes
# 47 44
#
# 91
# Answer 'yes' or 'no' based on the intention of the response:Do you watch Game of Thrones?I do. I'm a super fan of it (not the last season though haha).</s>
# Prediction: no Actual yes
# 47 45
#
# 92
# Answer 'yes' or 'no' based on the intention of the response:So is this the best brand?Pediatricians recommend this.</s>
# Prediction: yes Actual yes
# 48 45
#
# 93
# Answer 'yes' or 'no' based on the intention of the response:Ahh I see. That is a much harder task, no?yea you can first dump your brain and wait until technology advances to wake up</s>
# Prediction: yes Actual yes
# 49 45
#
# 94
# Answer 'yes' or 'no' based on the intention of the response:you like it?it's amazing. the buildings are so tall and there's a lot of diversity of cultures</s>
# Prediction: yes Actual yes
# 50 45
#
# 95
# Answer 'yes' or 'no' based on the intention of the response:Do you think you will be able to finish your report by five o'clock today?Not a chance. I'll be busy in meetings all day.</s>
# Prediction: no Actual no
# 51 45
#
# 96
# Answer 'yes' or 'no' based on the intention of the response:Does she know how to play a piano?Now it is like second nature to her.</s>
# Prediction: no Actual yes
# 51 46
#
# 97
# Answer 'yes' or 'no' based on the intention of the response:What, scared of heights?I dunno, man. After what happened to Johnny Gobs</s>
# Prediction: yes Actual yes
# 52 46
#
# 98
# Answer 'yes' or 'no' based on the intention of the response:have you ever tried it?i have a couple years ago. it's quite a unique experience</s>
# Prediction: yes Actual yes
# 53 46
#
# 99
# Answer 'yes' or 'no' based on the intention of the response:Do you like cooking?lol what's a klutz? yeah I like, but I'm not good</s>
# Prediction: yes Actual yes
# 54 46
#
# 100
# Answer 'yes' or 'no' based on the intention of the response:Are there more like you?Dead. All dead. Long time.</s>
# Prediction: no Actual no
# 55 46
#
# 101
# Answer 'yes' or 'no' based on the intention of the response:Haha, are you in med school? Or are you pre-med?no high school actually haha</s>
# Prediction: no Actual no
# 56 46
#
# 102
# Answer 'yes' or 'no' based on the intention of the response:Have you eve seen anything so wonderful in your entire life?Wow, cool! But, err, what is it?</s>
# Prediction: yes Actual no
# 56 47
#
# 103
# Answer 'yes' or 'no' based on the intention of the response:Do you believe in miracles?Lol. No. I know too many people whose lives suck.</s>
# Prediction: yes Actual no
# 56 48
#
# 104
# Answer 'yes' or 'no' based on the intention of the response:Are you sad about losing your job?It turned out to be a blessing in disguise.</s>
# Prediction: no Actual no
# 57 48
#
# 105
# Answer 'yes' or 'no' based on the intention of the response:Do you have steady hands?Kind of I think</s>
# Prediction: yes Actual yes
# 58 48
#
# 106
# Answer 'yes' or 'no' based on the intention of the response:Not sure if you have tried it or notI think I haven't y</s>
# Prediction: no Actual no
# 59 48
#
# 107
# Answer 'yes' or 'no' based on the intention of the response:Is he - dead?Oh, I - I can't make out a heartbeat.</s>
# Prediction: no Actual yes
# 59 49
#
# 108
# Answer 'yes' or 'no' based on the intention of the response:Have you ever made them yourself?no. only eat them</s>
# Prediction: no Actual no
# 60 49
#
# 109
# Answer 'yes' or 'no' based on the intention of the response:Do you have any holiday plans for christmas?Nothing much, I am going to sit back and relax at home</s>
# Prediction: no Actual no
# 61 49
#
# 110
# Answer 'yes' or 'no' based on the intention of the response:You... live here?Long time. Long, long time.</s>
# Prediction: no Actual yes
# 61 50
#
# 111
# Answer 'yes' or 'no' based on the intention of the response:that's football right?Yes, I think the traffic will be bad.</s>
# Prediction: yes Actual yes
# 62 50
#
# 112
# Answer 'yes' or 'no' based on the intention of the response:Do you know what kind of medicine you want to practice?I wanna be a brain surgeon!!</s>
# Prediction: no Actual yes
# 62 51
#
# 113
# Answer 'yes' or 'no' based on the intention of the response:know what I mean?I think I sort of understand :)</s>
# Prediction: yes Actual yes
# 63 51
#
# 114
# Answer 'yes' or 'no' based on the intention of the response:Are you planning something fun for Thanksgiving?Not yet. I always made my last minute schedule planning.</s>
# Prediction: no Actual no
# 64 51
#
# 115
# Answer 'yes' or 'no' based on the intention of the response:Does it mean that I'm crazy?Crazy isn't a psychiatric diagnosis, Fred.</s>
# Prediction: yes Actual no
# 64 52
#
# 116
# Answer 'yes' or 'no' based on the intention of the response:Well, will you ask Mrs. Brill?Not for a hundred quid, ma'am.</s>
# Prediction: no Actual no
# 65 52
#
# 117
# Answer 'yes' or 'no' based on the intention of the response:Are you Zuria?He's inside.</s>
# Prediction: yes Actual no
# 65 53
#
# 118
# Answer 'yes' or 'no' based on the intention of the response:Did you catch the Warriors game last night btw?no, i was busy catching up with a friend.</s>
# Prediction: no Actual no
# 66 53
#
# 119
# Answer 'yes' or 'no' based on the intention of the response:Any big plans for the upcoming holidays?Yes, I will be going skiing in Tahoe over the holidays.</s>
# Prediction: yes Actual yes
# 67 53
#
# 120
# Answer 'yes' or 'no' based on the intention of the response:do you know any french?Yeah I grew up speaking it. It's pretty much mandatory here</s>
# Prediction: yes Actual yes
# 68 53
#
# 121
# Answer 'yes' or 'no' based on the intention of the response:Did you go there?I didn't need to --</s>
# Prediction: yes Actual no
# 68 54
#
# 122
# Answer 'yes' or 'no' based on the intention of the response:Have you had a chance to wear your new shirt yet?I have been trying to exchange it for a larger size.</s>
# Prediction: no Actual no
# 69 54
#
# 123
# Answer 'yes' or 'no' based on the intention of the response:Is your business profitable?we’re in the black this year.</s>
# Prediction: yes Actual yes
# 70 54
#
# 124
# Answer 'yes' or 'no' based on the intention of the response:Do you with money at those horse vaulting competitions?Yeah some. enough to get by</s>
# Prediction: no Actual yes
# 70 55
#
# 125
# Answer 'yes' or 'no' based on the intention of the response:Let's have a pizza for dinner.I am on diet.</s>
# Prediction: no Actual no
# 71 55
#
# 126
# Answer 'yes' or 'no' based on the intention of the response:Do you ski a lot?nope, whenever I went fast I fell badly</s>
# Prediction: no Actual no
# 72 55
#
# 127
# Answer 'yes' or 'no' based on the intention of the response:And have you any other truths to tell me?You already know what they are.</s>
# Prediction: no Actual yes
# 72 56
#
# 128
# Answer 'yes' or 'no' based on the intention of the response:Have you seen Frasier?Not yet What's it about?</s>
# Prediction: yes Actual no
# 72 57
#
# 129
# Answer 'yes' or 'no' based on the intention of the response:Did you like it?I was glad when it was over.</s>
# Prediction: yes Actual no
# 72 58
#
# 130
# Answer 'yes' or 'no' based on the intention of the response:So they're not going to hurt us?does it look like any of them are trying to hurt you?</s>
# Prediction: no Actual no
# 73 58
#
# 131
# Answer 'yes' or 'no' based on the intention of the response:Is the room warm?It is as cold as ice.</s>
# Prediction: yes Actual no
# 73 59
#
# 132
# Answer 'yes' or 'no' based on the intention of the response:Do you realize how perfectly unmatched we are?It's made up about one thing though.</s>
# Prediction: yes Actual yes
# 74 59
#
# 133
# Answer 'yes' or 'no' based on the intention of the response:You're blaming us?I am thanking you.</s>
# Prediction: no Actual no
# 75 59
#
# 134
# Answer 'yes' or 'no' based on the intention of the response:do you think that hurts?from a high enough distance, yes?</s>
# Prediction: yes Actual yes
# 76 59
#
# 135
# Answer 'yes' or 'no' based on the intention of the response:Do you have any interest in that?I'd love to try!</s>
# Prediction: yes Actual yes
# 77 59
#
# 136
# Answer 'yes' or 'no' based on the intention of the response:do you have a feast planned?yup! gonna have dinner with family what books are you gonna read?</s>
# Prediction: no Actual yes
# 77 60
#
# 137
# Answer 'yes' or 'no' based on the intention of the response:Do you enjoy the cold?Sure hate it! Limits our ability to go out even for a walk! Its good that we don't get to suffer extreme cold weather!</s>
# Prediction: yes Actual no
# 77 61
#
# 138
# Answer 'yes' or 'no' based on the intention of the response:Oh hey Dad, can we eat now?Just wait till we get home.</s>
# Prediction: no Actual no
# 78 61
#
# 139
# Answer 'yes' or 'no' based on the intention of the response:do you ice skate yourself?Barely I don't think I can, in conscience, call it that I kind of just pull myself along the sides</s>
# Prediction: no Actual no
# 79 61
#
# 140
# Answer 'yes' or 'no' based on the intention of the response:Do you have any plans?Yes, no shopping plans but I can't wait to eat thanksgiving food. yay for pumpkin pie</s>
# Prediction: no Actual yes
# 79 62
#
# 141
# Answer 'yes' or 'no' based on the intention of the response:Did he get a huge profit?He sold his website for peanut.</s>
# Prediction: no Actual no
# 80 62
#
# 142
# Answer 'yes' or 'no' based on the intention of the response:Are you angry at me?To err is human, to forgive divine.</s>
# Prediction: no Actual no
# 81 62
#
# 143
# Answer 'yes' or 'no' based on the intention of the response:Is he a careful investor?He never puts all of his eggs in one basket</s>
# Prediction: no Actual yes
# 81 63
#
# 144
# Answer 'yes' or 'no' based on the intention of the response:Do you have big plans?Yes! I am going to Hawaii!</s>
# Prediction: no Actual yes
# 81 64
#
# 145
# Answer 'yes' or 'no' based on the intention of the response:Do you want me to spoil it for you?Yes!</s>
# Prediction: yes Actual yes
# 82 64
#
# 146
# Answer 'yes' or 'no' based on the intention of the response:Does that work?Yeah, I think so.</s>
# Prediction: yes Actual yes
# 83 64
#
# 147
# Answer 'yes' or 'no' based on the intention of the response:Do you want a cigar, Father?They're very bad for you.</s>
# Prediction: no Actual no
# 84 64
#
# 148
# Answer 'yes' or 'no' based on the intention of the response:Can he walk now?He is as strong as an ox.</s>
# Prediction: no Actual yes
# 84 65
#
# 149
# Answer 'yes' or 'no' based on the intention of the response:Have you done it before?Nope, never! I know a couple of friends who have.</s>
# Prediction: no Actual no
# 85 65
#
# 150
# Answer 'yes' or 'no' based on the intention of the response:Do you think that Dr. Luby will organize a theatre trip to New York this year?I have already signed up for it.</s>
# Prediction: no Actual yes
# 85 66
#
# 151
# Answer 'yes' or 'no' based on the intention of the response:Would you say that to someone who lost a loved one - or some similar circumstance?Well, no, of course not! Let me stick with “Ah that sucks” by itself, then.</s>
# Prediction: no Actual no
# 86 66
#
# 152
# Answer 'yes' or 'no' based on the intention of the response:Did I scare you?I just did a freaky number, not like a fantasy trip, but... So I'm kinda.</s>
# Prediction: no Actual no
# 87 66
#
# 153
# Answer 'yes' or 'no' based on the intention of the response:are you going to cook the turkey yourself?yeah. I'm gonna watch a video to figure it out</s>
# Prediction: no Actual yes
# 87 67
#
# 154
# Answer 'yes' or 'no' based on the intention of the response:Can we schedule something for next week?Sure! What does your Saturday look like?</s>
# Prediction: yes Actual yes
# 88 67
#
# 155
# Answer 'yes' or 'no' based on the intention of the response:do you like stuffing?Stuffing! yes please! I wonder what would be the excitement levels for christmas then :)</s>
# Prediction: no Actual yes
# 88 68
#
# 156
# Answer 'yes' or 'no' based on the intention of the response:Are you guys going to win?You can bet on it.</s>
# Prediction: yes Actual yes
# 89 68
#
# 157
# Answer 'yes' or 'no' based on the intention of the response:is there nothing we can do about Mr. Tumnus?well.. there's hope!</s>
# Prediction: no Actual no
# 90 68
#
# 158
# Answer 'yes' or 'no' based on the intention of the response:Are you gonna marry Lucy?Are you out of your gourd?</s>
# Prediction: yes Actual no
# 90 69
#
# 159
# Answer 'yes' or 'no' based on the intention of the response:Do you like travelling?Yes I do. But haven’t been to many places yet</s>
# Prediction: yes Actual yes
# 91 69
#
# 160
# Answer 'yes' or 'no' based on the intention of the response:Ever tried that before?Nope I haven't, have you been fishing before?</s>
# Prediction: no Actual no
# 92 69
#
# 161
# Answer 'yes' or 'no' based on the intention of the response:Did you buy an expensive car?Our car cost us an arm and a leg.</s>
# Prediction: no Actual yes
# 92 70
#
# 162
# Answer 'yes' or 'no' based on the intention of the response:Did you hear something?Hmm, I wonder what this one is?</s>
# Prediction: yes Actual no
# 92 71
#
# 163
# Answer 'yes' or 'no' based on the intention of the response:Are you going for the party?Is the pope Catholic?</s>
# Prediction: yes Actual yes
# 93 71
#
# 164
# Answer 'yes' or 'no' based on the intention of the response:are you participating in the mentorship program this cycle?I have done it in the past but not this cycle.</s>
# Prediction: no Actual no
# 94 71
#
# 165
# Answer 'yes' or 'no' based on the intention of the response:I wonder, Bob, if you can handle my car?It's an ordinary six cylinder.</s>
# Prediction: no Actual yes
# 94 72
#
# 166
# Answer 'yes' or 'no' based on the intention of the response:Have you guys made any other plans?not yet! totally up for it. thanks for inviting!</s>
# Prediction: no Actual no
# 95 72
#
# 167
# Answer 'yes' or 'no' based on the intention of the response:Busy with your work?Yes, actually it was a very busy day!</s>
# Prediction: yes Actual yes
# 96 72
#
# 168
# Answer 'yes' or 'no' based on the intention of the response:You're leaving?It has been a pleasure my Queen.</s>
# Prediction: no Actual yes
# 96 73
#
# 169
# Answer 'yes' or 'no' based on the intention of the response:is it raining pretty bad today?yeah, can walk too far to see all the foodtruck options</s>
# Prediction: yes Actual yes
# 97 73
#
# 170
# Answer 'yes' or 'no' based on the intention of the response:Couldn't I have some more now?I don't want to ruin you appetite.</s>
# Prediction: yes Actual no
# 97 74
#
# 171
# Answer 'yes' or 'no' based on the intention of the response:Do you like tacos?yeah my favorite is taco fish</s>
# Prediction: no Actual yes
# 97 75
#
# 172
# Answer 'yes' or 'no' based on the intention of the response:Not to be elitist but...that's a real job?Yeah! It is a very demanding job, requires a carefully crafted set of skills. They pay is really good too.</s>
# Prediction: yes Actual yes
# 98 75
#
# 173
# Answer 'yes' or 'no' based on the intention of the response:Have you done this before?nah! Just watched a lot of youtube videos</s>
# Prediction: no Actual yes
# 98 76
#
# 174
# Answer 'yes' or 'no' based on the intention of the response:Are you also doing science?no, I'm bad at Science.</s>
# Prediction: no Actual no
# 99 76
#
# 175
# Answer 'yes' or 'no' based on the intention of the response:Am I better than your sister?You can't hold a candle to my sister.</s>
# Prediction: no Actual no
# 100 76
#
# 176
# Answer 'yes' or 'no' based on the intention of the response:I'm thinking about getting a Switch, would you recommend it?Yes! There are a lot of really great games on the Switch.</s>
# Prediction: no Actual yes
# 100 77
#
# 177
# Answer 'yes' or 'no' based on the intention of the response:Changing topics, Do you believe in an afterlife?Yes. I wonder if I'm in it right now. How would I know?</s>
# Prediction: yes Actual yes
# 101 77
#
# 178
# Answer 'yes' or 'no' based on the intention of the response:Do you like music?yea definitely! I love singing Karaoke. my wife is a pianist</s>
# Prediction: no Actual yes
# 101 78
#
# 179
# Answer 'yes' or 'no' based on the intention of the response:Are you going to talk to Mark?I want to get this off my chest.</s>
# Prediction: yes Actual yes
# 102 78
#
# 180
# Answer 'yes' or 'no' based on the intention of the response:Are you planning anything fun for December?Nothing exciting. I'll be posted up at home for the most part. I did a lot of travelling this year so my budget would have stopped me even if I wasn't sick.</s>
# Prediction: no Actual no
# 103 78
#
# 181
# Answer 'yes' or 'no' based on the intention of the response:Did you also visit cambodia and other neighboring places?Yes. Laos and Cambodia are the two neighboring countries. Cambodia has an exotic culture. They sell spiders, scorpions, and grasshoppers as street food! It took a lot of courage for me to try them.</s>
# Prediction: no Actual yes
# 103 79
#
# 182

# %%
print("Correct Predictions: ",correct)
print("Incorrect Predictions:", wrong)
print("Accuracy:", correct/total)
# Out:
# Correct Predictions:  103
# Incorrect Predictions: 79
# Accuracy: 0.5659340659340659

# %%
recall = tp / (tp + fn)
precision = tp / (tp + fp)
f1_score = (2 * recall * precision) / (recall + precision) 
print("Recall: ", recall)
print("Precision: ", precision)
print("F1 score: ", f1_score)
# Out:
# Recall:  0.5185185185185185
# Precision:  0.6829268292682927
# F1 score:  0.5894736842105263
